# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import ParameterGrid  #
import joblib
import os
import sys

# 定义早停回调和模型保存回调
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=20, restore_best_weights=True)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint('best_dl_model.h5', save_best_only=True)

# %%
###############################################################################input
ref_dir = "/data/input/Files/ReferenceData/sunjinghua/ProjPTB/data"
exp_file = ref_dir + "/" + "sam_path_group.list.773.mlmiRNA.TPM.07"
train_labels_file= ref_dir + "/" + "sam.group.sPTB.train"
feature_genes_file = "/data/work/python" + "/" + "feature.gene.list"
caseName = "sPTB"
contName = "TB"

test_labels_file = ref_dir + "/" + "sam.group.sPTB.valid1"
outdir= "/data/work/result.DL/valid1"

#exp_file = sys.argv[0]
#train_labels_file = sys.argv[1]
#test_labels_file = sys.argv[2]
#feature_genes_file = sys.argv[3]
#caseName = sys.argv[4]
#contName = sys.argv[5]

expr_data = pd.read_csv(exp_file, sep="\t", index_col=0)  # 输入文件1：表达量
train_labels = pd.read_csv(train_labels_file, sep="\t")         # 输入文件2：训练集标签
test_labels = pd.read_csv(test_labels_file,sep="\t")           # 输入文件3：测试集标签
feature_genes = pd.read_csv(feature_genes_file, sep="\t", header=None)[0].tolist()  # 输入文件4：特征基因
# 将标签转换为数值类型
label_mapping = {caseName: 1, contName: 0}
train_labels['group'] = train_labels['group'].map(label_mapping)
test_labels['group'] = test_labels['group'].map(label_mapping)
#print(expr_data.tail(10).iloc[:, -10:])
#print(f"表达量数据维度: {expr_data.shape} (样本×基因)")
#print(f"特征基因匹配度: {len(feature_genes)} / {expr_data.shape[1]}")

# %%
##################################################################################### preprocess
########################### pick training and testing data
train_samples = set(train_labels['sample'])
test_samples = set(test_labels['sample'])
train_samples_list = list(train_samples)
test_samples_list = list(test_samples)

train_expr = expr_data[train_samples_list]
test_expr = expr_data[test_samples_list]

train_expr_feature_genes = train_expr.T[feature_genes]
test_expr_feature_genes = test_expr.T[feature_genes]

######################## scale data set
def scale_data(data):
    means = data.mean(axis=0)
    stds = data.std(axis=0)
    scaled_data = (data - means) / stds
    return scaled_data, means, stds

# 对训练集进行标准化
train_expr_scaled, train_means, train_stds = scale_data(train_expr_feature_genes)

# 使用训练集的均值和标准差对测试集进行标准化
test_expr_scaled = (test_expr_feature_genes - train_means) / train_stds

############################# merge expression and lables
train_labels.set_index('sample', inplace=True)
merged_train_data = train_expr_scaled.merge(train_labels, left_index=True, right_index=True)   ## label is group
#train_expr_feature_genes1 = train_expr_feature_genes.merge(train_labels, left_index=True, right_index=True)
test_labels.set_index('sample', inplace=True)
merged_test_data = test_expr_scaled.merge(test_labels, left_index=True, right_index=True)  ## label is group

X_train = merged_train_data.iloc[:, :-1]
y_train =  merged_train_data['group']
X_test = merged_test_data.iloc[:, :-1]
y_test =  merged_test_data['group']

# %%
############################################################################################## training 
# 定义深度学习模型架构
def create_dl_model(input_dim):
    model = models.Sequential()
    model.add(layers.Input(shape=(input_dim,)))
    model.add(layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# 超参数配置
dl_params = {
    'batch_size': [32, 64],
    'epochs': [100, 200],
    'learning_rate': [0.001, 0.0005],
    'optimizer': [tf.keras.optimizers.Adam, tf.keras.optimizers.RMSprop]
}

# 交叉验证配置
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=1024)
best_auc = 0
best_model = None
cv_results = []

# 执行交叉验证
fold_no = 1
for train_idx, val_idx in kfold.split(X_train.values, y_train.values):
    print(f'Training Fold {fold_no}...')
    
    # 数据划分
    X_tr, X_val = X_train.values[train_idx], X_train.values[val_idx]
    y_tr, y_val = y_train.values[train_idx], y_train.values[val_idx]
    
    # 数据标准化
    #scaler = StandardScaler().fit(X_tr)
    #X_tr_scaled = scaler.transform(X_tr)
    #X_val_scaled = scaler.transform(X_val)
    
    # 超参数网格搜索
    for params in ParameterGrid(dl_params):
        print(f'  Trying params: {params}')
        
        # 创建模型
        model = create_dl_model(X_tr.shape[1])
        model.compile(
            optimizer=params['optimizer'](learning_rate=params['learning_rate']),
            loss='binary_crossentropy',
            metrics=[tf.keras.metrics.AUC(name='auc')]
        )
        
        # 训练模型
        history = model.fit(
            X_tr, y_tr,
            validation_data=(X_val, y_val),
            epochs=params['epochs'],
            batch_size=params['batch_size'],
            callbacks=[early_stopping, model_checkpoint],
            verbose=0
        )
        
        # 验证集评估
        val_auc = max(history.history['val_auc'])
        if val_auc > best_auc:
            best_auc = val_auc
            best_model = tf.keras.models.load_model('best_dl_model.h5')
            best_params = params
        
         # 保存每折的验证结果
        cv_results.append({
            'fold': fold_no,
            'params': params,
            'val_auc': val_auc,
            'best_epoch': len(history.history['val_auc'])
        })
    
    fold_no += 1

# 使用全部训练数据重新训练最佳模型
#scaler_full = StandardScaler().fit(X_train.values)
#X_train_scaled = scaler_full.transform(X_train.values)
best_model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'])

# 保存交叉验证结果
cv_results_df = pd.DataFrame(cv_results)
cv_results_df.to_csv(os.path.join(outdir, 'DL_cv_results.csv'), index=False)
# Out:
# Training Fold 1...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Training Fold 2...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Training Fold 3...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Training Fold 4...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Training Fold 5...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Training Fold 6...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Training Fold 7...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Training Fold 8...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Training Fold 9...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Training Fold 10...
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 100, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.adam.Adam'>}
#   Trying params: {'batch_size': 64, 'epochs': 200, 'learning_rate': 0.0005, 'optimizer': <class 'keras.optimizers.optimizer_experimental.rmsprop.RMSprop'>}
# Epoch 1/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1965 - auc: 0.9963
# Epoch 2/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1782 - auc: 0.9979
# Epoch 3/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1720 - auc: 0.9992
# Epoch 4/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1584 - auc: 0.9996
# Epoch 5/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1605 - auc: 0.9999
# Epoch 6/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1602 - auc: 0.9997
# Epoch 7/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1493 - auc: 1.0000
# Epoch 8/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1483 - auc: 1.0000
# Epoch 9/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1463 - auc: 0.9998
# Epoch 10/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1508 - auc: 0.9999
# Epoch 11/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1384 - auc: 1.0000
# Epoch 12/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1395 - auc: 1.0000
# Epoch 13/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1337 - auc: 1.0000
# Epoch 14/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1336 - auc: 1.0000
# Epoch 15/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1407 - auc: 0.9999
# Epoch 16/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1403 - auc: 0.9999
# Epoch 17/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1348 - auc: 1.0000
# Epoch 18/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1323 - auc: 1.0000
# Epoch 19/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1309 - auc: 1.0000
# Epoch 20/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1240 - auc: 1.0000
# Epoch 21/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1292 - auc: 0.9999
# Epoch 22/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1259 - auc: 1.0000
# Epoch 23/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1289 - auc: 1.0000
# Epoch 24/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1230 - auc: 1.0000
# Epoch 25/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1198 - auc: 1.0000
# Epoch 26/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1166 - auc: 1.0000
# Epoch 27/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1189 - auc: 1.0000
# Epoch 28/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1207 - auc: 1.0000
# Epoch 29/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1153 - auc: 1.0000
# Epoch 30/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1142 - auc: 1.0000
# Epoch 31/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1130 - auc: 1.0000
# Epoch 32/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1146 - auc: 1.0000
# Epoch 33/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1150 - auc: 1.0000
# Epoch 34/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1152 - auc: 1.0000
# Epoch 35/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1114 - auc: 1.0000
# Epoch 36/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1089 - auc: 1.0000
# Epoch 37/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1114 - auc: 1.0000
# Epoch 38/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1087 - auc: 1.0000
# Epoch 39/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1076 - auc: 1.0000
# Epoch 40/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1097 - auc: 1.0000
# Epoch 41/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1028 - auc: 1.0000
# Epoch 42/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1110 - auc: 0.9999
# Epoch 43/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1065 - auc: 1.0000
# Epoch 44/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1093 - auc: 0.9998
# Epoch 45/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1023 - auc: 1.0000
# Epoch 46/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1055 - auc: 0.9999
# Epoch 47/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1085 - auc: 0.9999
# Epoch 48/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1021 - auc: 1.0000
# Epoch 49/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1063 - auc: 1.0000
# Epoch 50/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1023 - auc: 1.0000
# Epoch 51/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0974 - auc: 1.0000
# Epoch 52/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1009 - auc: 1.0000
# Epoch 53/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0996 - auc: 1.0000
# Epoch 54/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0988 - auc: 1.0000
# Epoch 55/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0977 - auc: 1.0000
# Epoch 56/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1122 - auc: 0.9996
# Epoch 57/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0935 - auc: 1.0000
# Epoch 58/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0980 - auc: 1.0000
# Epoch 59/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0910 - auc: 1.0000
# Epoch 60/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0994 - auc: 1.0000
# Epoch 61/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0961 - auc: 1.0000
# Epoch 62/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0982 - auc: 1.0000
# Epoch 63/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0979 - auc: 1.0000
# Epoch 64/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0920 - auc: 1.0000
# Epoch 65/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0944 - auc: 1.0000
# Epoch 66/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0962 - auc: 0.9999
# Epoch 67/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0959 - auc: 1.0000
# Epoch 68/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1014 - auc: 0.9992
# Epoch 69/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0916 - auc: 1.0000
# Epoch 70/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0940 - auc: 1.0000
# Epoch 71/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0959 - auc: 1.0000
# Epoch 72/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0929 - auc: 1.0000
# Epoch 73/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0921 - auc: 0.9999
# Epoch 74/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0963 - auc: 0.9999
# Epoch 75/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0887 - auc: 1.0000
# Epoch 76/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0922 - auc: 1.0000
# Epoch 77/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0919 - auc: 1.0000
# Epoch 78/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0863 - auc: 1.0000
# Epoch 79/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0864 - auc: 1.0000
# Epoch 80/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0912 - auc: 1.0000
# Epoch 81/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0866 - auc: 1.0000
# Epoch 82/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0850 - auc: 1.0000
# Epoch 83/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0931 - auc: 0.9999
# Epoch 84/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0859 - auc: 1.0000
# Epoch 85/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0840 - auc: 1.0000
# Epoch 86/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0869 - auc: 1.0000
# Epoch 87/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0894 - auc: 1.0000
# Epoch 88/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0862 - auc: 1.0000
# Epoch 89/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0880 - auc: 1.0000
# Epoch 90/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0911 - auc: 0.9999
# Epoch 91/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0924 - auc: 0.9998
# Epoch 92/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0843 - auc: 1.0000
# Epoch 93/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0839 - auc: 1.0000
# Epoch 94/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0856 - auc: 1.0000
# Epoch 95/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0838 - auc: 1.0000
# Epoch 96/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0842 - auc: 1.0000
# Epoch 97/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0829 - auc: 1.0000
# Epoch 98/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0863 - auc: 0.9999
# Epoch 99/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0802 - auc: 1.0000
# Epoch 100/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0811 - auc: 1.0000
# Epoch 101/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0807 - auc: 1.0000
# Epoch 102/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0806 - auc: 1.0000
# Epoch 103/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0817 - auc: 1.0000
# Epoch 104/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0858 - auc: 0.9999
# Epoch 105/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0762 - auc: 1.0000
# Epoch 106/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0817 - auc: 1.0000
# Epoch 107/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0750 - auc: 1.0000
# Epoch 108/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0786 - auc: 1.0000
# Epoch 109/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0768 - auc: 1.0000
# Epoch 110/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0761 - auc: 1.0000
# Epoch 111/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0848 - auc: 1.0000
# Epoch 112/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0765 - auc: 1.0000
# Epoch 113/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0800 - auc: 1.0000
# Epoch 114/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0800 - auc: 1.0000
# Epoch 115/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0782 - auc: 1.0000
# Epoch 116/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0787 - auc: 1.0000
# Epoch 117/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0755 - auc: 1.0000
# Epoch 118/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0746 - auc: 1.0000
# Epoch 119/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0803 - auc: 1.0000
# Epoch 120/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0726 - auc: 1.0000
# Epoch 121/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0744 - auc: 1.0000
# Epoch 122/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0824 - auc: 1.0000
# Epoch 123/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0749 - auc: 1.0000
# Epoch 124/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0802 - auc: 1.0000
# Epoch 125/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0708 - auc: 1.0000
# Epoch 126/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0768 - auc: 1.0000
# Epoch 127/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0760 - auc: 1.0000
# Epoch 128/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0813 - auc: 1.0000
# Epoch 129/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0762 - auc: 1.0000
# Epoch 130/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0754 - auc: 1.0000
# Epoch 131/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0727 - auc: 1.0000
# Epoch 132/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0756 - auc: 1.0000
# Epoch 133/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0743 - auc: 1.0000
# Epoch 134/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0785 - auc: 0.9999
# Epoch 135/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0923 - auc: 0.9993
# Epoch 136/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0777 - auc: 1.0000
# Epoch 137/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0730 - auc: 1.0000
# Epoch 138/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0744 - auc: 1.0000
# Epoch 139/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0801 - auc: 0.9992
# Epoch 140/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0768 - auc: 1.0000
# Epoch 141/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0694 - auc: 1.0000
# Epoch 142/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0727 - auc: 1.0000
# Epoch 143/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0746 - auc: 1.0000
# Epoch 144/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0688 - auc: 1.0000
# Epoch 145/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0708 - auc: 1.0000
# Epoch 146/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0823 - auc: 0.9998
# Epoch 147/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0746 - auc: 0.9999
# Epoch 148/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0721 - auc: 1.0000
# Epoch 149/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0747 - auc: 1.0000
# Epoch 150/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0810 - auc: 0.9998
# Epoch 151/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0731 - auc: 1.0000
# Epoch 152/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0714 - auc: 1.0000
# Epoch 153/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0731 - auc: 0.9999
# Epoch 154/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0685 - auc: 1.0000
# Epoch 155/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0877 - auc: 0.9969
# Epoch 156/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0725 - auc: 1.0000
# Epoch 157/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0800 - auc: 0.9999
# Epoch 158/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0762 - auc: 1.0000
# Epoch 159/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0704 - auc: 1.0000
# Epoch 160/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0718 - auc: 1.0000
# Epoch 161/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0691 - auc: 1.0000
# Epoch 162/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0732 - auc: 0.9999
# Epoch 163/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0714 - auc: 1.0000
# Epoch 164/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0838 - auc: 0.9995
# Epoch 165/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0693 - auc: 1.0000
# Epoch 166/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0779 - auc: 0.9999
# Epoch 167/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0659 - auc: 1.0000
# Epoch 168/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0694 - auc: 1.0000
# Epoch 169/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0845 - auc: 0.9992
# Epoch 170/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0741 - auc: 0.9999
# Epoch 171/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0673 - auc: 1.0000
# Epoch 172/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0701 - auc: 1.0000
# Epoch 173/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0675 - auc: 1.0000
# Epoch 174/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0688 - auc: 1.0000
# Epoch 175/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0663 - auc: 1.0000
# Epoch 176/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0693 - auc: 1.0000
# Epoch 177/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0635 - auc: 1.0000
# Epoch 178/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0657 - auc: 1.0000
# Epoch 179/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0676 - auc: 1.0000
# Epoch 180/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0663 - auc: 1.0000
# Epoch 181/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0648 - auc: 1.0000
# Epoch 182/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0667 - auc: 1.0000
# Epoch 183/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0701 - auc: 1.0000
# Epoch 184/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0708 - auc: 1.0000
# Epoch 185/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0622 - auc: 1.0000
# Epoch 186/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0741 - auc: 0.9997
# Epoch 187/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0684 - auc: 1.0000
# Epoch 188/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0644 - auc: 1.0000
# Epoch 189/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0648 - auc: 1.0000
# Epoch 190/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0658 - auc: 1.0000
# Epoch 191/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0736 - auc: 0.9998
# Epoch 192/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0645 - auc: 1.0000
# Epoch 193/200
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0767 - auc: 0.9994
# Epoch 194/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0658 - auc: 1.0000
# Epoch 195/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0654 - auc: 1.0000
# Epoch 196/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0680 - auc: 1.0000
# Epoch 197/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0715 - auc: 1.0000
# Epoch 198/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0608 - auc: 1.0000
# Epoch 199/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0670 - auc: 1.0000
# Epoch 200/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0636 - auc: 1.0000

# %%
################################### training risk score and AUC
#X_train = merged_train_data.iloc[:, :-1]
#y_train =  merged_train_data['group']
train_proba = best_model.predict(X_train).flatten()
train_auc = roc_auc_score(y_train, train_proba)
train_auc
train_risk_scores = pd.DataFrame({
    'SampleID': X_train.index,
    'RiskScore': train_proba,
    'Diagnosis': y_train
    })
train_risk_scores.to_csv(os.path.join(outdir, 'DL_train_risk_scores.csv'), index=False)

################################### testing risk score and AUC
X_test = merged_test_data.iloc[:, :-1]
y_test =  merged_test_data['group']
test_proba = best_model.predict(X_test).flatten()
test_auc = roc_auc_score(y_test, test_proba)  
test_auc
test_risk_scores = pd.DataFrame({
    'SampleID': X_test.index,
    'RiskScore': test_proba,
    'Diagnosis': y_test
    })
test_risk_scores.to_csv(os.path.join(outdir, 'DL_test_risk_scores.csv'), index=False)
#################################3 AUC
with open(os.path.join(outdir, "DL_auc_results.txt"), "w") as f:
    f.write(f"Test AUC: {test_auc:.4f}\n")
    f.write(f"Train AUC: {train_auc:.4f}\n")

######################################## save model
best_model.save(os.path.join(outdir, 'DL_best_dl_model.h5'))
# Out:
# 13/13 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
